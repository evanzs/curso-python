# %% [markdown]
# ## grafico de setores ou pizza
# # um circulo dividido proporcionalmente entre as frequencias observadas das categorias.
#
# # dicado:
#
#  - para comparar o valor de uma categoria com o TOTAL
#  - para numero de categorias pequenas de no max 6-7

# %%
import matplotlib.pyplot as plt
import seaborn as sns

y = [1,2,3,4,5,6]
x = ['n1','n2','n3','n4','n5','n6']
x2 = ['variaveis grandes 1','variaveis grandes 2','variaveis grandes 3','variaveis grandes 4','variaveis grandes 5','variaveis grandes 6']

# %%
plt.pie(y,labels=x2)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f92e945f7c0>,
# ...
#  [Text(1.087713908390803, 0.16394649582471824, 'variaveis grandes 1'),
#   Text(0.9088626448409262, 0.6196520740002058, 'variaveis grandes 2'),
#   Text(0.2447729879062314, 1.0724207124032321, 'variaveis grandes 3'),
#   Text(-0.8063571098828889, 0.7481899567231004, 'variaveis grandes 4'),
#   Text(-0.9088626013289132, -0.6196521378206009, 'variaveis grandes 5'),
#   Text(0.6858388884465332, -0.8600145458621173, 'variaveis grandes 6')])

# %%
# para rancar esse monte de msg
plt.pie(y,labels=x2)
plt.show()

# %%
plt.pie(y,labels=x2, radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f92e6f514f0>,
# ...
#  [Text(2.175427816781606, 0.32789299164943647, 'variaveis grandes 1'),
#   Text(1.8177252896818523, 1.2393041480004117, 'variaveis grandes 2'),
#   Text(0.4895459758124628, 2.1448414248064642, 'variaveis grandes 3'),
#   Text(-1.6127142197657778, 1.4963799134462008, 'variaveis grandes 4'),
#   Text(-1.8177252026578263, -1.2393042756412018, 'variaveis grandes 5'),
#   Text(1.3716777768930664, -1.7200290917242347, 'variaveis grandes 6')])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.show()
#
# AttributeError: module 'seaborn' has no attribute 'show'
