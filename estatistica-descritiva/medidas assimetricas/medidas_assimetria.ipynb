# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'
df_flowers = pd.read_csv(url,sep=',')
df_flowers.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ## MEDIDAS DE CURTOSE
#
# # K = (Q3 - Q1)/ 2*(P90 - P10)

# %%
df = df_flowers.iloc[:,:4]
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
## k = (Q3 - Q1) / 2 * (P90 - P10)
dividendo  = df.quantile(0.75)  - df.quantile(0.25)
divisor = (df.quantile(0.90) - df.quantile(0.10))*2 
K = dividendo / divisor;K

# K mais proximo de 0.264 levemente concentrado do centro
# k < 0.263 , muito concentrado em torno do centro
# K > 0.263, MUITO CONCETRADO EM TORNO DO CENTRO
# Out:
# sepal.length    0.309524
# sepal.width     0.225225
# petal.length    0.397727
# petal.width     0.375000
# dtype: float64

# %%
df.kurt()
# Out:
# sepal.length   -0.552064
# sepal.width     0.228249
# petal.length   -1.402103
# petal.width    -1.340604
# dtype: float64

# %% [markdown]
# ## REPRESENTANDO GRAFICAMENTE
# # LEPTOCURTICA

# %%
# !pip install scipy
# Out:
# ...
#   Using cached scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Gerar dados com diferentes níveis de curtose
data_normal = np.random.normal(loc=0, scale=1, size=10000)
data_leptokurtic = np.random.standard_t(df=3, size=10000)
data_super_leptokurtic = np.random.standard_t(df=2, size=10000)

# Criar um DataFrame Pandas
df = pd.DataFrame({'Normal': data_normal,
                   'Leptocúrtica': data_leptokurtic,
                   'Super Leptocúrtica': data_super_leptokurtic})

# Plotar histogramas
df.plot(kind='density', xlim=(-5, 5), figsize=(10, 6))
plt.title('Distribuições com diferentes níveis de curtose')
plt.xlabel('Valores')
plt.ylabel('Densidade')

plt.show()
